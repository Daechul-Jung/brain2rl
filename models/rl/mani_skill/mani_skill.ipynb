# %%
import torch
import numpy as np

# %%
b, t, h, a = 8, 128, 1, 7

x = torch.rand((b, t, h, a))

# %%
x[:, -1].shape
# Out:
# torch.Size([8, 1, 7])

# %%
np.array([1,2,3,4,5])[None, None, :, None].shape
# Out:
# (1, 1, 5, 1)
